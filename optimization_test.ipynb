# %% [markdown]
# # Test of the Optimization function elaborated

# %%
import numpy as np
import pandas as pd
import control as ct
import control.optimal as opt
import matplotlib.pyplot as plt

# from analysis_irrigation import IrrigationAnalysis

# Trying out by the beggining.
from DSSATTools import (
    Crop, SoilProfile, WeatherData, WeatherStation,
    Management, DSSAT, TabularSubsection
)
from datetime import datetime, timedelta

# %% [markdown]
# ## Test 01 - Basics

# %%
# Random weather data
DATES = pd.date_range('2000-01-01', '2002-12-31')
N = len(DATES)
df = pd.DataFrame(
    {
    'tn':   np.random.gamma(10, 1, N),
    'rad':  np.random.gamma(10, 1.5, N),
    'prec': [0.0]* N,
    'rh':   100 * np.random.beta(1.5, 1.15, N),
    },
    index=DATES,
)
df['TMAX'] = df.tn + np.random.gamma(5., .5, N)
df.head()

# %%
# Create a WeatherData instance
WTH_DATA = WeatherData(
    df,
    variables={
        'tn': 'TMIN', 'TMAX': 'TMAX',
        'prec': 'RAIN', 'rad': 'SRAD',
        'rh': 'RHUM'
    }
)
# Create a WheaterStation instance
wth = WeatherStation(
    WTH_DATA, 
    {'ELEV': 33, 'LAT': 0, 'LON': 0, 'INSI': 'dpoes'}
)

# %%
# Soil instance from default soil profile
soil = SoilProfile(default_class='SIC')

# Crop
crop = Crop('potato')
# Check how the cultivar looks like
crop.cultivar['IB0001']

# %%
# Creating irrigation schedule
schedule = pd.DataFrame([
    (datetime(2000,1,15), 80),
    (datetime(2000,1,30), 60),
    (datetime(2000,2,15), 40),
    (datetime(2000,3,1),  20)
], columns = ['date', 'IRVAL'])
schedule['IDATE'] = schedule.date.dt.strftime('%y%j')
schedule['IROP'] = 'IR001' # Code to define the irrigation operation
schedule = schedule[['IDATE', 'IROP', 'IRVAL']]
schedule

# %%
# Management instance
man = Management(
    cultivar='IB0001',
    planting_date=DATES[10],
)
# Modify harvest to Maturity
man.simulation_controls['HARVS'] = 'M'
# Set the irrigation schedule
man.irrigation['table'] = TabularSubsection(schedule)
# Set irrigation control as reported schedule
man.simulation_controls['IRRIG'] = 'R'

# The definition of this parameters is mandatory for roots (???)
man.planting_details['table']['PLWT'] = 1500
man.planting_details['table']['SPRL'] = 2

# Check the simulation control value for Irrigation
man.simulation_controls['IRRIG']

# %%
dssat = DSSAT()
dssat.setup()
dssat.run(
    soil=soil, weather=wth, crop=crop, management=man,
)

# %%
# Modify the irrigation amounts and check output
schedule['IRVAL'] = [50, 50, 50, 50]
man.irrigation['table'] = TabularSubsection(schedule)
dssat.run(
    soil=soil, weather=wth, crop=crop, management=man,
)

# %%
# Print available outputs
dssat.OUTPUT_LIST

# Save the output
output_1 = dssat.output['PlantGro']
output_1.head()

# %%
# Terminate the DSSAT instance
dssat.close()

# %% [markdown]
# ## Test 02 - Scipy Optimization

# %%
from optimization import optimization_irri
import numpy as np
from scipy.optimize import minimize
from scipy.optimize import Bounds

# %%
###### SETUP OF THE PROBLEM

# Random weather data
DATES = pd.date_range('2000-01-01', '2000-02-28')
N = len(DATES)
df = pd.DataFrame(
    {
    'tn':   np.random.gamma(10, 1, N),
    'rad':  np.random.gamma(10, 1.5, N),
    'prec': [0.0]* N,
    'rh':   100 * np.random.beta(1.5, 1.15, N),
    },
    index=DATES,
)
df['TMAX'] = df.tn + np.random.gamma(5., .5, N)

# Create a WeatherData instance
WTH_DATA = WeatherData(
                        df,
                        variables={
                        'tn': 'TMIN', 'TMAX': 'TMAX',
                        'prec': 'RAIN', 'rad': 'SRAD',
                        'rh': 'RHUM'
                    }
)
# Create a WheaterStation instance
wth = WeatherStation(
    WTH_DATA, 
    {'ELEV': 33, 'LAT': 0, 'LON': 0, 'INSI': 'dpoes'}
)

# Soil instance from default soil profile
soil = SoilProfile(default_class='SIC')
# Crop
crop = Crop('potato')
# Check how the cultivar looks like
crop.cultivar['IB0001']

# Management instance
man = Management(
    cultivar='IB0001',
    planting_date=DATES[10],
)
# Modify harvest to Maturity
man.simulation_controls['HARVS'] = 'M'
# Set irrigation control as reported schedule
man.simulation_controls['IRRIG'] = 'R'

# The definition of this parameters is mandatory for roots (???)
man.planting_details['table']['PLWT'] = 1500
man.planting_details['table']['SPRL'] = 2

# %%
irval = [0,  0, 0 , 0 ]
optimization_irri(irval)

# %%
# Definition of the optimization problem

bounds = Bounds([2,2,2,2], [30,30,30,30])

irval0 = np.array([0, 0, 0, 0])
res = minimize(optimization_irri, irval0, method='nelder-mead', options={'xatol': 1e-8, 'disp': True})

# %%
print(res.x)

# %% [markdown]
# ## Test 03 - Nevergrad

# %%
from optimization import optimization_irri
import numpy as np
import nevergrad as ng

# %%
###### SETUP OF THE PROBLEM

# Random weather data
DATES = pd.date_range('2000-01-01', '2000-02-28')
N = len(DATES)
df = pd.DataFrame(
    {
    'tn':   np.random.gamma(10, 1, N),
    'rad':  np.random.gamma(10, 1.5, N),
    'prec': [0.0]* N,
    'rh':   100 * np.random.beta(1.5, 1.15, N),
    },
    index=DATES,
)
df['TMAX'] = df.tn + np.random.gamma(5., .5, N)

# Create a WeatherData instance
WTH_DATA = WeatherData(
                        df,
                        variables={
                        'tn': 'TMIN', 'TMAX': 'TMAX',
                        'prec': 'RAIN', 'rad': 'SRAD',
                        'rh': 'RHUM'
                    }
)
# Create a WheaterStation instance
wth = WeatherStation(
    WTH_DATA, 
    {'ELEV': 33, 'LAT': 0, 'LON': 0, 'INSI': 'dpoes'}
)

# Soil instance from default soil profile
soil = SoilProfile(default_class='SIC')
# Crop
crop = Crop('potato')
# Check how the cultivar looks like
crop.cultivar['IB0001']

# Management instance
man = Management(
    cultivar='IB0001',
    planting_date=DATES[10],
)
# Modify harvest to Maturity
man.simulation_controls['HARVS'] = 'M'
# Set irrigation control as reported schedule
man.simulation_controls['IRRIG'] = 'R'

# The definition of this parameters is mandatory for roots (???)
man.planting_details['table']['PLWT'] = 1500
man.planting_details['table']['SPRL'] = 2

# %%
max_val_irrig = 60
irval = [max_val_irrig, max_val_irrig, max_val_irrig, max_val_irrig]
optimization_irri(irval)
# Out:
# C:\Users\leopo\AppData\Local\Temp\dssatlwxgawav created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatlwxgawav.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   240   125   218     0   -99      0  212
# 1.4183075555555555

# %%
# Definition of the optimization problem

# Discrete, ordered
param = ng.p.TransitionChoice(range(max_val_irrig), repetitions=4)
optimizer = ng.optimizers.DiscreteOnePlusOne(parametrization=param, budget=100)
# optimizer = ng.optimizers.DiscreteOnePlusOne(parametrization=param, budget=100, num_workers=1)

recommendation = optimizer.provide_recommendation()
for _ in range(optimizer.budget):
    x = optimizer.ask()
    loss = optimization_irri(x.value)
    optimizer.tell(x, loss)

recommendation = optimizer.provide_recommendation()
print(recommendation.value)
# Out:
# C:\Users\leopo\AppData\Local\Temp\dssatjvjgkacc created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatjvjgkacc.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   120   123   102     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatmcycbcbc created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatmcycbcbc.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4605  2483     0   100   123    83     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssativlnathw created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssativlnathw.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4605  2483     0   103   123    86     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssaticzwdwxq created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssaticzwdwxq.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   143   115   133     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatjwpujojb created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatjwpujojb.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  3291  1574     0    95   100   100     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssativnntanh created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssativnntanh.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   135   123   117     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatezuculjx created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatezuculjx.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  1959   885     0    65    96    74     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatsouqwklr created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatsouqwklr.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4605  2483     0    88   123    71     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatkfpqhdql created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatkfpqhdql.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4605  2483     0    95   123    78     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatsuidsxqu created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatsuidsxqu.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  3562  1662     0    73   107    71     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatyvtxyauq created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatyvtxyauq.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4605  2483     0   110   123    93     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatgkmtmvxn created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatgkmtmvxn.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4605  2483     0   111   123    94     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatjwodpvto created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatjwodpvto.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   107   124    88     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatwxiublht created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatwxiublht.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  3145  1500     0    65    97    74     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatqhcvokej created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatqhcvokej.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   103   124    84     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssathohmwuah created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssathohmwuah.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  3740  1771     0    76   116    66     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatdbxydkbb created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatdbxydkbb.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   111   124    92     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatkdwkqhdu created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatkdwkqhdu.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0    98   123    81     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatkurltagq created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatkurltagq.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  2161   958     0    58   101    63     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatekbseejd created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatekbseejd.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  3808  1816     0    88   109    85     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatumprsvkn created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatumprsvkn.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  3243  1469     0    71   113    64     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatfclquawi created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatfclquawi.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  25 -99   949   453     0    33    63    75     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatthgekkgb created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatthgekkgb.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   134   124   115     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssattsrzajpi created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssattsrzajpi.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  2943  1377     0    58    91    73     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatwbxpmptn created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatwbxpmptn.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0    97   123    79     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssathnctvloh created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssathnctvloh.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   126   123   108     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatymjpyjls created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatymjpyjls.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   127   123   109     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatuvvxotkw created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatuvvxotkw.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4605  2483     0   102   123    85     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssattfjgjrix created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssattfjgjrix.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4544  2442     0   100   122    83     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatlylzqhmt created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatlylzqhmt.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4620  2508     0    87   123    69     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatykirxmiu created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatykirxmiu.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     

# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  3352  1513     0    68   114    59     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatrithydok created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatrithydok.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4147  2366     0    88   101    92     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatbhmshdye created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatbhmshdye.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  3820  2060     0    82    98    89     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatcntzghjl created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatcntzghjl.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   144   123   126     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatckwyhmpz created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatckwyhmpz.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  3299  1570     0    57    94    68     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatgwdycjad created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatgwdycjad.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   132   123   114     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatrqkzodre created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatrqkzodre.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   128   123   110     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatpfootpcg created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatpfootpcg.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4606  2485     0    90   123    73     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatsvlgexub created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatsvlgexub.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   104   123    86     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatfaptldby created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatfaptldby.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4006  1979     0    70   118    57     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssathozvdykw created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssathozvdykw.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   102   123    84     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatqkrxqmiu created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatqkrxqmiu.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   126   123   108     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssathwahhxza created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssathwahhxza.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   125   123   107     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatainberic created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatainberic.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   123   123   105     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatsttxjgdl created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatsttxjgdl.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   162   124   143     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatdhtxxoqf created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatdhtxxoqf.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4109  2230     0   109   109   106     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatcukcuyca created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatcukcuyca.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   136   123   118     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatprzjcfgw created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatprzjcfgw.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   114   123    96     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatetiecbvu created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatetiecbvu.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   104   123    86     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatsqmlhaik created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatsqmlhaik.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   142   123   124     0   -99      0  212
# C:\Users\leopo\AppData\Local\Temp\dssatpjvesxdr created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatpjvesxdr.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  4628  2541     0   133   123   115     0   -99      0  212
# (30, 36, 18, 3)

# %%
# Test of the value found
# irval = [30, 36, 18, 3] - loss: 0.5546 (optimal found)
# irval = [36, 30, 10, 2] - loss: 0.78297 
# irval = [30, 30, 10, 7] - loss: 0.833
irval = [31, 5, 30, 10]
optimization_irri(irval)
# Out:
# C:\Users\leopo\AppData\Local\Temp\dssatsqjnaznt created.
# Static files copied to C:\Users\leopo\AppData\Local\Temp\dssatsqjnaznt.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  28 -99  3429  2025     0    76   114    67     0   -99      0  212
# 1.5691757777777777

# %%
# Definition of the optimization problem

# Parametrization
instrum = ng.p.Instrumentation(
    ng.p.Array(shape=(4,)).set_bounds(lower=0, upper=50)
)

# optimization on x as an array of shape (4,) (instrum)
optimizer = ng.optimizers.NGOpt(parametrization=instrum, budget=100)
recommendation = optimizer.minimize(optimization_irri, verbosity=5)

# optimization on x as an array of shape (4,)  ->>> What is the budget?
# optimizer = ng.optimizers.NGOpt(parametrization=4, budget=100)

# define a constraint on first variable of x:
# optimizer.parametrization.register_cheap_constraint(lambda x: x[0] >= 0)
# optimizer.parametrization.register_cheap_constraint(lambda x: x[1] >= 0)
# optimizer.parametrization.register_cheap_constraint(lambda x: x[2] >= 0)
# optimizer.parametrization.register_cheap_constraint(lambda x: x[3] >= 0)

# What is verbosity?
# recommendation = optimizer.minimize(optimization_irri, verbosity=4)  # best value

print(recommendation.value)
