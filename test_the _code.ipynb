# %% [markdown]
# ### S8: Irrigation control

# %% [markdown]
# Import all the necessary library

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from analysis_irrigation import IrrigationAnalysis

# %% [markdown]
# Initialize the class IrrigationAnalysis, you can initialize just writing ```IrrigationAnalysis``` or provinding parameters
#
# > dates: Tuple
# >>Optional. Range of dates, default ('2022-04-01', '2022-09-15')
#
# >crop_type: srt
# >>Optional. Type of crop, default Potato
#
# >soil_class: srt
# >>Optional. Soil class
#
# >>Sand=S; Loamy Sand=LS; Sandy Loam=SL; Loam=L; Silty Loam=SIL; Silt=SI; Sandy Clay Loam=SCL; Clay Loam=CL; Silty Clay Loam=SICL; Sandy Clay=SC; Silty Clay=SIC; Clay=C.

# %%
irri = IrrigationAnalysis(dates = ('2022-04-01', '2022-09-15'), crop_type='Potato', soil_class = 'SIL')

# %%
irri.afficher(irchange=[30,40,5,70,80], show_graph=True)
# Out:
# C:\Users\MELANI~1\AppData\Local\Temp\Expe created.
# Static files copied to C:\Users\MELANI~1\AppData\Local\Temp\Expe.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  32 -99  8396  7868   154    54   227    50     0   -99      0  141
# C:\Users\MELANI~1\AppData\Local\Temp\Expe created.
# Static files copied to C:\Users\MELANI~1\AppData\Local\Temp\Expe.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  32 -99  8698  8169   154   225   237    91     0   -99      0  141
#          Dates  TWAD  NEW_TWAD
# 0   2022-04-01     0         0
# 1   2022-04-02     0         0
# 2   2022-04-03     0         0
# 3   2022-04-04     0         0
# 4   2022-04-05     0         0
# ..         ...   ...       ...
# 164 2022-09-12  8385      8686
# ...

# %%
irri.irrigation(show_graph=True)
# Out:
# (1,)
#
#
#
# C:\Users\MELANI~1\AppData\Local\Temp\Expe created.
# Static files copied to C:\Users\MELANI~1\AppData\Local\Temp\Expe.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  32 -99  8396  7868   154    54   227    50     0   -99      0  141
#
#
#
# C:\Users\MELANI~1\AppData\Local\Temp\Expe created.
# Static files copied to C:\Users\MELANI~1\AppData\Local\Temp\Expe.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  32 -99  8674  8119   154    54   227    50     0   -99      0  141
#
#
#
# C:\Users\MELANI~1\AppData\Local\Temp\Expe created.
# Static files copied to C:\Users\MELANI~1\AppData\Local\Temp\Expe.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
# ...

# %%
irri.results(type_ir='A').plot()
plt.title("Irrigation vs dates")
plt.ylabel("Irrigation")
plt.xlabel("Dates")
plt.show()
# Out:
# C:\Users\MELANI~1\AppData\Local\Temp\Expe created.
# Static files copied to C:\Users\MELANI~1\AppData\Local\Temp\Expe.
# RUN    TRT FLO MAT TOPWT HARWT  RAIN  TIRR   CET  PESW  TNUP  TNLF   TSON TSOC
#            dap dap kg/ha kg/ha    mm    mm    mm    mm kg/ha kg/ha  kg/ha t/ha
#   1 PT   1  32 -99  8863  8320   154   131   261    92     0   -99      0  141
